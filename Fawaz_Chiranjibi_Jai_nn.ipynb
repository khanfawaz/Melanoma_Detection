# %% [markdown]
# <a href="https://colab.research.google.com/github/khanfawaz/Melanoma_Detection/blob/main/Fawaz_Chiranjibi_Jai_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **`Problem statement:`** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# **Importing Skin Cancer Data**

# %% [markdown]
# **`To do:`** Take necessary actions to read the data

# %% [markdown]
# **Importing all the important libraries**

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Train")
data_dir_test = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Test")

# %%
data_dir_train
# Out:
# PosixPath('/content/drive/MyDrive/CNN_assignment/Train')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %% [markdown]
# Load using keras.preprocessing

# %% [markdown]
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
  )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# Visualize the data

# %% [markdown]
# **`Todo`**, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img

### your code goes here, you can use training or validation data to visualize

#Creating Dictionary for store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))

#Visualize image
plt.figure(figsize=(10,10))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(img_height,img_width)))
    plt.title(c)

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.

# %% [markdown]
# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.

# %% [markdown]
# Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Create the model**

# %% [markdown]
# **`Todo:`** Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# **Compile the model**

# %% [markdown]
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Train the model**

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 56/56 [==============================] - 548s 3s/step - loss: 2.0496 - accuracy: 0.2121 - val_loss: 2.0322 - val_accuracy: 0.1700
# Epoch 2/20
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0365 - accuracy: 0.1981 - val_loss: 1.9867 - val_accuracy: 0.2349
# Epoch 3/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9435 - accuracy: 0.2640 - val_loss: 1.8709 - val_accuracy: 0.2975
# Epoch 4/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.8697 - accuracy: 0.2991 - val_loss: 1.8425 - val_accuracy: 0.3289
# Epoch 5/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.7400 - accuracy: 0.3577 - val_loss: 1.6978 - val_accuracy: 0.3781
# Epoch 6/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.6415 - accuracy: 0.3973 - val_loss: 1.6056 - val_accuracy: 0.4452
# Epoch 7/20
# 56/56 [==============================] - 5s 91ms/step - loss: 1.5896 - accuracy: 0.4180 - val_loss: 1.7432 - val_accuracy: 0.4094
# Epoch 8/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.4786 - accuracy: 0.4637 - val_loss: 1.5034 - val_accuracy: 0.4720
# Epoch 9/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.4729 - accuracy: 0.4537 - val_loss: 1.6045 - val_accuracy: 0.4318
# Epoch 10/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.3723 - accuracy: 0.5039 - val_loss: 1.6007 - val_accuracy: 0.4541
# Epoch 11/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.2620 - accuracy: 0.5463 - val_loss: 1.8459 - val_accuracy: 0.3736
# Epoch 12/20
# 56/56 [==============================] - 5s 91ms/step - loss: 1.2061 - accuracy: 0.5670 - val_loss: 1.7549 - val_accuracy: 0.4653
# Epoch 13/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.1436 - accuracy: 0.5921 - val_loss: 1.5465 - val_accuracy: 0.4855
# Epoch 14/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.2578 - accuracy: 0.5452 - val_loss: 1.7912 - val_accuracy: 0.4362
# Epoch 15/20
# 56/56 [==============================] - 5s 91ms/step - loss: 1.0444 - accuracy: 0.6177 - val_loss: 1.8608 - val_accuracy: 0.4609
# Epoch 16/20
# 56/56 [==============================] - 5s 90ms/step - loss: 0.9908 - accuracy: 0.6401 - val_loss: 2.0642 - val_accuracy: 0.4541
# Epoch 17/20
# 56/56 [==============================] - 5s 90ms/step - loss: 0.9644 - accuracy: 0.6362 - val_loss: 1.7354 - val_accuracy: 0.4877
# Epoch 18/20
# 56/56 [==============================] - 5s 90ms/step - loss: 0.8509 - accuracy: 0.6881 - val_loss: 1.9324 - val_accuracy: 0.4855
# Epoch 19/20
# 56/56 [==============================] - 5s 90ms/step - loss: 0.8373 - accuracy: 0.6920 - val_loss: 2.1772 - val_accuracy: 0.4161
# Epoch 20/20
# 56/56 [==============================] - 5s 91ms/step - loss: 0.8053 - accuracy: 0.7109 - val_loss: 2.0531 - val_accuracy: 0.4966

# %% [markdown]
# **Visualizing training results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **`Todo:`** Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# **Observations on the first base model:**
#
# The model underwent 20 epochs of training.
# The model shows clear signs of overfitting.
# A notable gap exists between the training and validation accuracy.
#
# **Accuracy observations:**
#
# Training accuracy: Above 75-80%.
# Validation accuracy: Approximately 50-60%.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here
data_augumentation = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augumentation(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# **`Todo:`**
# Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
num_classes = 9
model = Sequential([ data_augumentation,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))

])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# **Compiling the model**

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      2432
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d_4 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 64)        51264
#
#  max_pooling2d_5 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        102464
#
#  max_pooling2d_6 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_1 (Dense)             (None, 9)                 278793
#
# =================================================================
# Total params: 460,585
# Trainable params: 460,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Training the model**

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 10s 121ms/step - loss: 2.0583 - accuracy: 0.2143 - val_loss: 1.9383 - val_accuracy: 0.2438
# Epoch 2/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.8866 - accuracy: 0.2991 - val_loss: 1.7332 - val_accuracy: 0.3781
# Epoch 3/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.6650 - accuracy: 0.3984 - val_loss: 1.6261 - val_accuracy: 0.4049
# Epoch 4/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6629 - accuracy: 0.3951 - val_loss: 1.6952 - val_accuracy: 0.4072
# Epoch 5/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6361 - accuracy: 0.4040 - val_loss: 1.5669 - val_accuracy: 0.4340
# Epoch 6/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.6034 - accuracy: 0.4291 - val_loss: 1.5404 - val_accuracy: 0.4720
# Epoch 7/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.5644 - accuracy: 0.4548 - val_loss: 1.5582 - val_accuracy: 0.4609
# Epoch 8/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.5248 - accuracy: 0.4542 - val_loss: 1.4491 - val_accuracy: 0.4765
# Epoch 9/20
# 56/56 [==============================] - 5s 98ms/step - loss: 1.4857 - accuracy: 0.4794 - val_loss: 1.4611 - val_accuracy: 0.4944
# Epoch 10/20
# 56/56 [==============================] - 6s 100ms/step - loss: 1.4942 - accuracy: 0.4777 - val_loss: 1.6961 - val_accuracy: 0.3915
# Epoch 11/20
# 56/56 [==============================] - 5s 98ms/step - loss: 1.4621 - accuracy: 0.4866 - val_loss: 1.4762 - val_accuracy: 0.4855
# Epoch 12/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.4323 - accuracy: 0.5084 - val_loss: 1.4955 - val_accuracy: 0.4944
# Epoch 13/20
# 56/56 [==============================] - 6s 100ms/step - loss: 1.4646 - accuracy: 0.4877 - val_loss: 1.4159 - val_accuracy: 0.4989
# Epoch 14/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.4221 - accuracy: 0.4989 - val_loss: 1.4737 - val_accuracy: 0.5123
# Epoch 15/20
# 56/56 [==============================] - 6s 100ms/step - loss: 1.4254 - accuracy: 0.5028 - val_loss: 1.4955 - val_accuracy: 0.4720
# Epoch 16/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.3997 - accuracy: 0.5033 - val_loss: 1.4726 - val_accuracy: 0.5078
# Epoch 17/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3819 - accuracy: 0.5279 - val_loss: 1.4781 - val_accuracy: 0.5056
# Epoch 18/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.3869 - accuracy: 0.5073 - val_loss: 1.4707 - val_accuracy: 0.4765
# Epoch 19/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3500 - accuracy: 0.5206 - val_loss: 1.4027 - val_accuracy: 0.5213
# Epoch 20/20
# 56/56 [==============================] - 5s 98ms/step - loss: 1.3453 - accuracy: 0.5318 - val_loss: 1.5351 - val_accuracy: 0.4653

# %% [markdown]
# **Visualizing the results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **`Todo:`** Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# **Observations from the second model:**
# Despite the absence of improvement in accuracy, a notable outcome is the successful resolution of the overfitting problem.
# This improvement can be attributed to the incorporation of data augmentation techniques.
# Although the overall accuracy remains unchanged, the model demonstrates a better ability to generalize and avoid overfitting issues.

# %% [markdown]
# **`Todo:`** Find the distribution of classes in the training dataset.
# Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
path_list=[]
lesion_list=[]
for i in class_names:

    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 1     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 2     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 3     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 4     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2235  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2236  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2237  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2238  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 1     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 2     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 3     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# 4     /content/drive/MyDrive/CNN_assignment/Train/ac...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2235  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2236  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2237  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
# 2238  /content/drive/MyDrive/CNN_assignment/Train/va...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# **`Todo:`** Write your findings here:
# - Which class has the least number of samples?
# - Which classes dominate the data in terms proportionate number of samples?
# Ans1: - Among the classes, squamous cell carcinoma has the fewest number of samples.
#
# Ans2: - The classes "actinic keratosis" and "dermatofibroma" have a proportional number of samples. Similarly, the classes "melanoma" and "pigmented benign keratosis" also have a proportional number of samples.

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# **`Todo:`** Rectify the class imbalance
# Context: You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use Augmentor, the following general procedure is followed:
#
# Instantiate a Pipeline object pointing to a directory containing your initial image data set.
# Define a number of operations to perform on this data set using your Pipeline object.
# Execute these operations by calling the Pipeline’s sample() method.

# %%
path_to_training_dataset="/content/drive/MyDrive/CNN_assignment/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AEFD0117E50>: 100%|██████████| 500/500 [00:26<00:00, 18.65 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AEFD0143AF0>: 100%|██████████| 500/500 [00:29<00:00, 17.15 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x
.jpg',
#  '/content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031258.jpg_5b81ea47-4d6e-4838-b36a-2d5c7add59ef.jpg',
#  '/content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031470.jpg_eb0c7563-abd9-4018-be51-a6ab25c67887.jpg',
#  '/content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025718.jpg_0b29978f-b448-479c-9e26-4e290b92a98f.jpg',
#  '/content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0024665.jpg_8de10e34-d866-4f3d-b13e-d1b13ed1e8b4.jpg',
#  '/content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030800.jpg_37cd04f7-9220-46e3-9624-0c7b6b7228c4.jpg',
#  '/content/drive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025467.jpg_1bef9144-7c43-4d91-9ece-afedf1bc301b.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-35-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added many images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# **`Todo:`** Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **`Todo:`** Create a training dataset

# %%
data_dir_train="/content/drive/MyDrive/CNN_assignment/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training', ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# **`Todo:`** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation", ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# **`Todo:`** Create your model (make sure to include normalization)

# %%
## your code goes here
model = Sequential([ data_augumentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %% [markdown]
# **`Todo:`** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# **`Todo:`** Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = history = model.fit(
          train_ds,
          validation_data=val_ds,
          epochs=epochs)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 169/169 [==============================] - 43s 218ms/step - loss: 1.8348 - accuracy: 0.2787 - val_loss: 1.6299 - val_accuracy: 0.3541
# Epoch 2/50
# 169/169 [==============================] - 36s 207ms/step - loss: 1.5935 - accuracy: 0.3837 - val_loss: 1.5387 - val_accuracy: 0.4076
# Epoch 3/50
# 169/169 [==============================] - 36s 210ms/step - loss: 1.4833 - accuracy: 0.4418 - val_loss: 1.4095 - val_accuracy: 0.4276
# Epoch 4/50
# 169/169 [==============================] - 38s 217ms/step - loss: 1.4177 - accuracy: 0.4540 - val_loss: 1.4066 - val_accuracy: 0.4447
# Epoch 5/50
# 169/169 [==============================] - 40s 232ms/step - loss: 1.4081 - accuracy: 0.4557 - val_loss: 1.3605 - val_accuracy: 0.4796
# Epoch 6/50
# 169/169 [==============================] - 40s 234ms/step - loss: 1.3567 - accuracy: 0.4700 - val_loss: 1.5376 - val_accuracy: 0.3875
# Epoch 7/50
# 169/169 [==============================] - 41s 236ms/step - loss: 1.3410 - accuracy: 0.4805 - val_loss: 1.3030 - val_accuracy: 0.4855
# Epoch 8/50
# 169/169 [==============================] - 41s 236ms/step - loss: 1.2919 - accuracy: 0.4987 - val_loss: 1.3555 - val_accuracy: 0.4655
# Epoch 9/50
# 169/169 [==============================] - 45s 259ms/step - loss: 1.2702 - accuracy: 0.5000 - val_loss: 1.2433 - val_accuracy: 0.4944
# Epoch 10/50
# 169/169 [==============================] - 38s 217ms/step - loss: 1.2471 - accuracy: 0.5221 - val_loss: 1.2730 - val_accuracy: 0.5137
# Epoch 11/50
# 169/169 [==============================] - 37s 213ms/step - loss: 1.1934 - accuracy: 0.5389 - val_loss: 1.1998 - val_accuracy: 0.5145
# Epoch 12/50
# 169/169 [==============================] - 37s 211ms/step - loss: 1.1742 - accuracy: 0.5427 - val_loss: 1.2459 - val_accuracy: 0.5152
# Epoch 13/50
# 169/169 [==============================] - 38s 218ms/step - loss: 1.1540 - accuracy: 0.5540 - val_loss: 1.5102 - val_accuracy: 0.4491
# Epoch 14/50
# 169/169 [==============================] - 38s 218ms/step - loss: 1.1505 - accuracy: 0.5610 - val_loss: 1.1480 - val_accuracy: 0.5330
# Epoch 15/50
# 169/169 [==============================] - 37s 214ms/step - loss: 1.1012 - accuracy: 0.5777 - val_loss: 1.1857 - val_accuracy: 0.5316
# Epoch 16/50
# 169/169 [==============================] - 37s 211ms/step - loss: 1.0646 - accuracy: 0.5894 - val_loss: 1.0703 - val_accuracy: 0.5687
# Epoch 17/50
# 169/169 [==============================] - 40s 233ms/step - loss: 1.0495 - accuracy: 0.5911 - val_loss: 1.0834 - val_accuracy: 0.5768
# Epoch 18/50
# 169/169 [==============================] - 37s 214ms/step - loss: 1.0300 - accuracy: 0.6027 - val_loss: 1.2237 - val_accuracy: 0.5264
# Epoch 19/50
# 169/169 [==============================] - 41s 236ms/step - loss: 1.0131 - accuracy: 0.6120 - val_loss: 1.0165 - val_accuracy: 0.5961
# Epoch 20/50
# 169/169 [==============================] - 41s 236ms/step - loss: 0.9707 - accuracy: 0.6231 - val_loss: 1.3012 - val_accuracy: 0.5286
# Epoch 21/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.9666 - accuracy: 0.6269 - val_loss: 1.0577 - val_accuracy: 0.5969
# Epoch 22/50
# 169/169 [==============================] - 36s 209ms/step - loss: 0.9421 - accuracy: 0.6350 - val_loss: 1.0675 - val_accuracy: 0.5694
# Epoch 23/50
# 169/169 [==============================] - 38s 212ms/step - loss: 0.9261 - accuracy: 0.6421 - val_loss: 1.0426 - val_accuracy: 0.5932
# Epoch 24/50
# 169/169 [==============================] - 38s 218ms/step - loss: 0.8949 - accuracy: 0.6584 - val_loss: 0.9696 - val_accuracy: 0.6273
# Epoch 25/50
# 169/169 [==============================] - 37s 211ms/step - loss: 0.8669 - accuracy: 0.6649 - val_loss: 1.0304 - val_accuracy: 0.5917
# Epoch 26/50
# 169/169 [==============================] - 38s 215ms/step - loss: 0.8261 - accuracy: 0.6810 - val_loss: 1.0045 - val_accuracy: 0.6073
# Epoch 27/50
# 169/169 [==============================] - 38s 219ms/step - loss: 0.8324 - accuracy: 0.6780 - val_loss: 0.8978 - val_accuracy: 0.6414
# Epoch 28/50
# 169/169 [==============================] - 36s 209ms/step - loss: 0.8101 - accuracy: 0.6945 - val_loss: 0.9761 - val_accuracy: 0.6362
# Epoch 29/50
# 169/169 [==============================] - 38s 218ms/step - loss: 0.8049 - accuracy: 0.6858 - val_loss: 0.9132 - val_accuracy: 0.6548
# Epoch 30/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.7818 - accuracy: 0.6918 - val_loss: 0.9653 - val_accuracy: 0.6466
# Epoch 31/50
# 169/169 [==============================] - 36s 208ms/step - loss: 0.7923 - accuracy: 0.6970 - val_loss: 0.9602 - val_accuracy: 0.6385
# Epoch 32/50
# 169/169 [==============================] - 37s 211ms/step - loss: 0.7545 - accuracy: 0.7085 - val_loss: 0.9090 - val_accuracy: 0.6607
# Epoch 33/50
# 169/169 [==============================] - 40s 234ms/step - loss: 0.7643 - accuracy: 0.7075 - val_loss: 0.8448 - val_accuracy: 0.6763
# Epoch 34/50
# 169/169 [==============================] - 36s 208ms/step - loss: 0.7345 - accuracy: 0.7155 - val_loss: 0.8984 - val_accuracy: 0.6637
# Epoch 35/50
# 169/169 [==============================] - 38s 212ms/step - loss: 0.7062 - accuracy: 0.7270 - val_loss: 0.8626 - val_accuracy: 0.6845
# Epoch 36/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.7170 - accuracy: 0.7242 - val_loss: 0.9089 - val_accuracy: 0.6674
# Epoch 37/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.6722 - accuracy: 0.7387 - val_loss: 0.8723 - val_accuracy: 0.6533
# Epoch 38/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.6675 - accuracy: 0.7459 - val_loss: 0.8509 - val_accuracy: 0.6726
# Epoch 39/50
# 169/169 [==============================] - 41s 235ms/step - loss: 0.6526 - accuracy: 0.7519 - val_loss: 0.8675 - val_accuracy: 0.6667
# Epoch 40/50
# 169/169 [==============================] - 41s 236ms/step - loss: 0.6253 - accuracy: 0.7647 - val_loss: 0.9650 - val_accuracy: 0.6318
# Epoch 41/50
# 169/169 [==============================] - 42s 240ms/step - loss: 0.6377 - accuracy: 0.7517 - val_loss: 0.8675 - val_accuracy: 0.6837
# Epoch 42/50
# 169/169 [==============================] - 42s 244ms/step - loss: 0.6523 - accuracy: 0.7543 - val_loss: 0.8716 - val_accuracy: 0.6815
# Epoch 43/50
# 169/169 [==============================] - 38s 217ms/step - loss: 0.6407 - accuracy: 0.7585 - val_loss: 0.9015 - val_accuracy: 0.6771
# Epoch 44/50
# 169/169 [==============================] - 38s 220ms/step - loss: 0.5996 - accuracy: 0.7693 - val_loss: 0.7965 - val_accuracy: 0.7023
# Epoch 45/50
# 169/169 [==============================] - 41s 236ms/step - loss: 0.6036 - accuracy: 0.7741 - val_loss: 0.8161 - val_accuracy: 0.6956
# Epoch 46/50
# 169/169 [==============================] - 41s 240ms/step - loss: 0.5820 - accuracy: 0.7782 - val_loss: 0.8911 - val_accuracy: 0.6741
# Epoch 47/50
# 169/169 [==============================] - 37s 211ms/step - loss: 0.5801 - accuracy: 0.7819 - val_loss: 0.8655 - val_accuracy: 0.7008
# Epoch 48/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.5745 - accuracy: 0.7834 - val_loss: 0.8466 - val_accuracy: 0.6919
# Epoch 49/50
# 169/169 [==============================] - 37s 215ms/step - loss: 0.5366 - accuracy: 0.7938 - val_loss: 0.8395 - val_accuracy: 0.6852
# Epoch 50/50
# 169/169 [==============================] - 40s 233ms/step - loss: 0.5638 - accuracy: 0.7882 - val_loss: 0.8346 - val_accuracy: 0.7001

# %% [markdown]
# **`Todo:`** Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
from tensorflow.keras.preprocessing.image import load_img
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[5], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 [==============================] - 0s 265ms/step
# Actual Class basal cell carcinoma
# Predictive Class squamous cell carcinoma

# %% [markdown]
# **Todo:** Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# The accuracy on the training data has improved by using the Augmentor library.
# But, the model still exhibits signs of overfitting.
#
# Potential solutions to address the overfitting issue include:
#
# - Adding more layers or neurons to the model.
# - Incorporating dropout layers to mitigate overfitting.
#
# Furthermore, the model's performance can be further enhanced by tuning the hyperparameters, which involves optimizing the values of parameters such as learning rate, batch size, and regularization strength.
